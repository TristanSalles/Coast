# %% [markdown]
# # Simple wave sediment modelling

# %% [markdown]
# :::{note}
# Using a wave propagation model based on linear wave theory, we investigate the cumulative effect of a given wave forcing condition on erosional and depositional trend across a regional coastal system.</div>
# :::
#
# ***
#
# **Content:**
# - [Model set-up](#setup)
# - [Model initialisation function](#init)
# - [Waves evolution](#evol)
# - [Sediment entrainment, transport & deposition](#sed)
#
# ***

# %% [markdown]
# Loading required modules for this exercise. The main module here is **wavesed** a piece of code that was developed for this course and that can be found on [GitHub](https://github.com/pyReef-model/wavesed)

# %%
# !cd wavesed/; f2py -c -m ocean ocean.f90
# Out:
# running build
# running config_cc
# unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# build_src
# building extension "ocean" sources
# f2py options: []
# f2py:> /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c
# creating /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6
# Reading fortran codes...
# 	Reading file 'ocean.f90' (format:free)
# Post-processing...
# 	Block: ocean
# 			Block: ocean
# 				Block: airymodel
# 				Block: transport
# 				Block: diffusion
# Post-processing (stage 2)...
# 	Block: ocean
# 		Block: unknown_interface
# 			Block: ocean
# 				Block: airymodel
# 				Block: transport
# 				Block: diffusion
# Building modules...
# 	Building module "ocean"...
# 		Constructing F90 module support for "ocean"...
# 		  Variables: pi onpi pi2 pion2 onpi2 grav
# 			Constructing wrapper function "ocean.airymodel"...
# 			  c,l,travel,waveh = airymodel(dx,dd,h0,depth,src,inland,shadow,[numrow,numcol])
# 			Constructing wrapper function "ocean.transport"...
# 			  dz,dist = transport(iter,depth,hent,transx,transy,[numrow,numcol])
# 			Constructing wrapper function "ocean.diffusion"...
# 			  depo = diffusion(oelev,dz,coeff,maxth,tstep,nstep,[numrow,numcol])
# 	Wrote C/API module "ocean" to file "/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c"
# 	Fortran 90 wrappers are saved to "/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/ocean-f2pywrappers2.f90"
#   adding '/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/fortranobject.c' to sources.
#   adding '/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6' to include_dirs.
# copying /Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/f2py/src/fortranobject.c -> /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6
# copying /Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/f2py/src/fortranobject.h -> /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6
#   adding '/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/ocean-f2pywrappers2.f90' to sources.
# build_src: building npy-pkg config files
# running build_ext
# customize UnixCCompiler
# customize UnixCCompiler using build_ext
# get_default_fcompiler: matching types: '['gnu95', 'nag', 'absoft', 'ibm', 'intel', 'gnu', 'g95', 'pg']'
# customize Gnu95FCompiler
# Found executable /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-gfortran
# Found executable /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-ld
# Found executable /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-ar
# Found executable /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-ranlib
# customize Gnu95FCompiler
# customize Gnu95FCompiler using build_ext
# building 'ocean' extension
# compiling C sources
# C compiler: x86_64-apple-darwin13.4.0-clang -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /Users/getafix/anaconda3/envs/coast/include -D_FORTIFY_SOURCE=2 -isystem /Users/getafix/anaconda3/envs/coast/include
#
# creating /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/var
# creating /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/var/folders
# creating /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/var/folders/px
# creating /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn
# creating /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T
# creating /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1
# creating /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6
# compile options: '-I/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6 -I/Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include -I/Users/getafix/anaconda3/envs/coast/include/python3.6m -c'
# x86_64-apple-darwin13.4.0-clang: /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c
# x86_64-apple-darwin13.4.0-clang: /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/fortranobject.c
# In file included from In file included from /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/fortranobject.c::162:
# :
# In file included from In file included from /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/fortranobject.h/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/fortranobject.h::1313:
# :
# In file included from In file included from /Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include/numpy/arrayobject.h/Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include/numpy/arrayobject.h::44:
# :
# In file included from In file included from /Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include/numpy/ndarrayobject.h/Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include/numpy/ndarrayobject.h::1212:
# :
# In file included from In file included from /Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include/numpy/ndarraytypes.h/Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include/numpy/ndarraytypes.h::18221822:
# :
# /Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h/Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h::1717::22::  warningwarning: : "Using deprecated NumPy API, disable it with "          "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]"Using deprecated NumPy API, disable it with "          "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#
# #warning "Using deprecated NumPy API, disable it with " \#warning "Using deprecated NumPy API, disable it with " \
#
#  ^ ^
#
# /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c:311:5: warning: misleading indentation; statement is not part of the previous 'if' [-Wmisleading-indentation]
#     f2py_success = int_from_pyobj(&shadow,shadow_capi,"ocean.ocean.airymodel() 7th argument (shadow) can't be converted to int");
#     ^
# /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c:305:3: note: previous statement is here
#   if (!PyArg_ParseTupleAndKeywords(capi_args,capi_keywds,\
#   ^
# /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c:562:5: warning: misleading indentation; statement is not part of the previous 'if' [-Wmisleading-indentation]
#     f2py_success = int_from_pyobj(&iter,iter_capi,"ocean.ocean.transport() 1st argument (iter) can't be converted to int");
#     ^
# /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c:556:3: note: previous statement is here
#   if (!PyArg_ParseTupleAndKeywords(capi_args,capi_keywds,\
#   ^
# /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c:775:5: warning: misleading indentation; statement is not part of the previous 'if' [-Wmisleading-indentation]
#     f2py_success = int_from_pyobj(&nstep,nstep_capi,"ocean.ocean.diffusion() 6th argument (nstep) can't be converted to int");
#     ^
# /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c:769:3: note: previous statement is here
#   if (!PyArg_ParseTupleAndKeywords(capi_args,capi_keywds,\
#   ^
# /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.c:109:12: warning: unused function 'f2py_size' [-Wunused-function]
# static int f2py_size(PyArrayObject* var, ...)
#            ^
# 5 warnings generated.
# 1 warning generated.
# compiling Fortran 90 module sources
# Fortran f77 compiler: /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -march=core2 -mtune=haswell -ftree-vectorize -fPIC -fstack-protector -O2 -pipe -isystem /Users/getafix/anaconda3/envs/coast/include -O3 -funroll-loops
# Fortran f90 compiler: /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-gfortran -Wall -g -fno-second-underscore -fPIC -march=core2 -mtune=haswell -ftree-vectorize -fPIC -fstack-protector -O2 -pipe -isystem /Users/getafix/anaconda3/envs/coast/include -O3 -funroll-loops
# Fortran fix compiler: /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -march=core2 -mtune=haswell -ftree-vectorize -fPIC -fstack-protector -O2 -pipe -isystem /Users/getafix/anaconda3/envs/coast/include -O3 -funroll-loops
# compile options: '-I/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6 -I/Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include -I/Users/getafix/anaconda3/envs/coast/include/python3.6m -c'
# extra options: '-J/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/ -I/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/'
# x86_64-apple-darwin13.4.0-gfortran:f90: ocean.f90
# compiling Fortran sources
# Fortran f77 compiler: /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -march=core2 -mtune=haswell -ftree-vectorize -fPIC -fstack-protector -O2 -pipe -isystem /Users/getafix/anaconda3/envs/coast/include -O3 -funroll-loops
# Fortran f90 compiler: /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-gfortran -Wall -g -fno-second-underscore -fPIC -march=core2 -mtune=haswell -ftree-vectorize -fPIC -fstack-protector -O2 -pipe -isystem /Users/getafix/anaconda3/envs/coast/include -O3 -funroll-loops
# Fortran fix compiler: /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -march=core2 -mtune=haswell -ftree-vectorize -fPIC -fstack-protector -O2 -pipe -isystem /Users/getafix/anaconda3/envs/coast/include -O3 -funroll-loops
# compile options: '-I/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6 -I/Users/getafix/anaconda3/envs/coast/lib/python3.6/site-packages/numpy/core/include -I/Users/getafix/anaconda3/envs/coast/include/python3.6m -c'
# extra options: '-J/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/ -I/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/'
# x86_64-apple-darwin13.4.0-gfortran:f90: /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/ocean-f2pywrappers2.f90
# /Users/getafix/anaconda3/envs/coast/bin/x86_64-apple-darwin13.4.0-gfortran -Wall -g -Wall -g -undefined dynamic_lookup -bundle -Wl,-pie -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-rpath,/Users/getafix/anaconda3/envs/coast/lib -L/Users/getafix/anaconda3/envs/coast/lib /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/oceanmodule.o /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/fortranobject.o /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/ocean.o /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1/src.macosx-10.9-x86_64-3.6/ocean-f2pywrappers2.o -L/Users/getafix/anaconda3/envs/coast/lib/gcc/x86_64-apple-darwin13.4.0/9.3.0 -L/Users/getafix/anaconda3/envs/coast/lib/gcc/x86_64-apple-darwin13.4.0/9.3.0/../../.. -L/Users/getafix/anaconda3/envs/coast/lib/gcc/x86_64-apple-darwin13.4.0/9.3.0/../../.. -lgfortran -o ./ocean.cpython-36m-darwin.so
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Removing build directory /var/folders/px/dgn5m62n7bjbrc1d3cplcv7m0000gn/T/tmpg2e34wx1

# %%
import time
import numpy as np
import wavesed.wave as ocean

# %matplotlib inline

# %% [markdown]
# ## <a name="setup"></a>  Model set-up
#
#
# The model requires several parameters to be defined before being run. The most important one being the initial bathymetry. For this example, we will use the region around [Fraser Island](https://www.google.com.au/maps/@-24.8590806,152.2555941,236264m/data=!3m1!1e3?hl=en) at a resolution of 1000 m. The _digital elevation model_ (DEM) comes from the [Project 3DGBR](http://eatlas.org.au/data/uuid/200aba6b-6fb6-443e-b84b-86b0bbdb53ac).
#
# <img src="../pracenv/figs/ex4-fig1.png" width="60%">
#
# The file is called **FraserDEM.csv** and is located in the **data** folder. It is made of 3 columns containing the X, Y, and Z coordinates.

# %% [markdown]
# ### Model domain / grid parameters
#
# It is possible to change the initial resolution by using the `rfac` parameter, as an example:
#
# + `rfac = 1` corresponds to a model at 1000 m resolution (similar to the initial DEM)
# + `rfac = 2` transforms the dataset to 2000 m resolution

# %%
# Bathymetric filename
bfile = '../pracenv/dataset/FraserDEM.csv'
# Resolution factor
rfac = 1

# %% [markdown]
# ### Definition of wave parameters
#
# Now we need to define the forcing parameters for our simulation:
#
# + `H0` the deep water wave height in [m],
# + `dir` the deep water wave source direction at the boundary in degrees (angle is defined counterclock wise from horizontal axis)
# + `wbase` the maximum depth for wave influence on seabed [m]
# + `slvl` the sea-level position in [m]

# %%
# Wave height
H0 = 2
# Wave direction at boundary 
dir = 0
# Maximum depth for wave influence (m)
wbase = 10
# Sea level position (m)
slvl = 0.
# Output figure name
outname = 'wdir0'

# %% [markdown]
# ### Definition of sediment parameters
#
# To estimate wave-induced sediment transport, this simple model only accounts for a single grain size that needs to be defined (`d50`).
#
# There are also additional parameters that can be set to perform longshore and diffusive transport but we will use the default values for this example...

# %%
# Mean grain size diameter in m
d50 = 0.0001

# %% [markdown]
# ## <a name="init"></a>  Model initialisation function
#
# Now that all the parameters are defined in our python environment, we can initialise the simulation by calling the wavesed module:

# %%
#help(ocean.wave.__init__)

# %%
wavesed = ocean.wave(filename=bfile, wavebase=wbase, resfac=rfac, dia=d50)

# %% [markdown]
# As you can see from the command above there are still some parameters that have not been passed to the module:
#
# + `slvl`
# + `dir`
# + `H0`
#
# These parameters are sent separately so that multiple climatic conditions could be simulate more easily.
#
# First we define the sea-level position `slvl`.

# %%
t0 = time.clock()
wavesed.findland(slvl)
print('Definition of shoreline position took (s):',time.clock()-t0)
# Out:
# Definition of shoreline position took (s): 0.004208999999999907

# %% [markdown]
# Initialising wave boundary direction `dir` is then done with the `wavesource` function:

# %%
wdir = wavesed.wavesource(dir)

# %% [markdown]
# ## <a name="evol"></a>  Waves evolution
#
# The waves are then transformed using the **linear wave theory** from deep (set-up conditions) to shallow water assuming shore-parallel depth contours.
#
# The orientation of wave fronts is determined by wave _celerity_ and _refraction_ due to depth variations.
#
# Travel time in the domain is calculated from **Huygen's principle** (using an order $\sqrt{5}$ approximation).
#
# Assuming no refraction or loss of energy due to bottom friction, wave power $P$ is conserved from deep to shallow water.

# %%
#help(wavesed.cmptwaves)

# %%
t0 = time.clock()
wavesed.cmptwaves(src=wdir, h0=H0, sigma=1.)
print('Wave evolution computation took (s): ',time.clock()-t0)
# Out:
# Wave evolution computation took (s):  0.34799899999999995

# %% [markdown]
# ### Plotting simulated wave characteristics
#
# A series of graph can be visualised to show the following characteristics:
#
# + _bathy_: coarse bathymetric map
# + _wlength_: coarse wave lenght map
# + _travel_: coarse wave travel time map
# + _wcelerity_: coarse wave celerity map
# + _wheight_: coarse wave height map
# + _wpower_: coarse wave power map
# + _ubot_: coarse wave induced bottom velocity map
# + _shear_: coarse wave induced shear stress map

# %%
#help(wavesed.plotData)

# %%
size = (8,8)
# i1 = 0 
# i2 = -1
# j1 = 0
# j2 = -1

# Zooming to a specific region
i1 = 80 
i2 = 250 
j1 = 0
j2 = 170 

wavesed.plotData(data='bathy', figsize=size, vmin=-100, vmax=100, 
                 fontsize=10, imin=i1, imax=i2, jmin=j1, jmax=j2)

wavesed.plotData(data='travel', figsize=size, tstep=100, vmin=0, vmax=5.e4, 
                 fontsize=10, imin=i1, imax=i2, jmin=j1, jmax=j2)

wavesed.plotData(data='wcelerity', figsize=size, vmin=0, vmax=15, 
                 fontsize=10, stream=3, imin=i1, imax=i2, jmin=j1, jmax=j2)

wavesed.plotData(data='ubot', figsize=size, vmin=0, vmax=2, 
                 fontsize=10, imin=i1, imax=i2, jmin=j1, jmax=j2)

wavesed.plotData(data='shear', figsize=size, vmin=-10, vmax=10, 
                  fontsize=10, imin=i1, imax=i2, jmin=j1, jmax=j2)

# %% [markdown]
# ## <a name="sed"></a>  Sediment entrainment, transport & deposition
#
# **Sediment entrainment** relates to wave induced shear stress.
#
# The transport is computed according to both wave direction and longshore transport. Deposition is dependent of shear stress and diffusion.

# %%
#help(wavesed.cmptsed)

# %%
t0 = time.clock()
wavesed.cmptsed(sigma=1.)
print('Sediment erosion/deposition computation took (s): ',time.clock()-t0)
# Out:
# Sediment erosion/deposition computation took (s):  0.33937099999999987

# %% [markdown]
# ### Plotting morphological changes
#
# Using the same plotting function (`plotData`), we can now plot the following metrics:
#
# + _ent_: coarse sediment entrainment map
# + _dz_: coarse erosion/deposition map

# %%
#help(wavesed.plotData)

# %%
size = (8,8)
# i1 = 0 
# i2 = -1
# j1 = 0
# j2 = -1

# Zooming to a specific region
i1 = 80 
i2 = 250 
j1 = 0
j2 = 170

wavesed.plotData(data='bathy', figsize=size, vmin=-100, vmax=100, 
                 fontsize=10, stream=0, imin=i1, imax=i2, jmin=j1, jmax=j2)

wavesed.plotData(data='ent', figsize=size, vmin=0., vmax=5., 
                 fontsize=10, stream=0, imin=i1, imax=i2, jmin=j1, jmax=j2)

wavesed.plotData(data='dz', figsize=size, vmin=-1., vmax=1., 
                 fontsize=10, stream=0, imin=i1, imax=i2, jmin=j1, jmax=j2) #, save=outname)

# %% [markdown]
# ## <a name="save"></a>  Saving wave/sedimentation data

# %%
#waveparams.outputCSV(filename='erodep.csv', seddata=1)

# %% [markdown]
# ***
# :::{note}
#
# 1. Change the initial wave direction conditions to 90 and then to 270. Evaluate the impact on the morphological patterns.
# 2. Change the resolution factor to see how it impacts on erosion/deposition resolution.</div>
#
# :::
# ***
